# %%
# %load_ext autoreload
# %autoreload 2

# %%
import time
import os
import datetime

# %%
# Out:
# E:\$RECYCLE.BIN\S-1-5-21-85109457-1470676203-2680213098-1001\desktop.ini old access time:2025-09-13 21:10:03
# E:\books\Hilary Glasman-Deal - Science research writing for non-native speakers of English (2020).pdf old access time:2025-09-13 21:10:43
# E:\gradDesign\1120200734-王浩铭-德育毕业论文.docx old access time:2025-09-13 21:10:04
# E:\intern\26\投递记录.xlsx old access time:2025-09-13 21:22:34
# E:\intern\26\王浩铭_CV.pdf old access time:2025-09-13 21:22:37
